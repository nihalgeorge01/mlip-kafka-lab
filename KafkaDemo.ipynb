# %% [markdown]
# # Kafka Demo
#
# ### Connect to Kafka Broker Server
# ```
# ssh -o ServerAliveInterval=60 -L 9092:localhost:9092 tunnel@128.2.204.215 -NTf
# ```
# pass: seaitunnel
#
#
# To kill connection at port:
# ```
# lsof -ti:9092 | xargs kill -9
# ```
#
# ### Setup
# ```
# python -m pip install kafka-python
# ```

# %%
from os import path
import sys, os
from datetime import datetime
from json import dumps, loads
from time import sleep
from random import randint
import numpy as np
# ssh -o ServerAliveInterval=60 -L 9092:localhost:9092 tunnel@128.2.24.106 -NTf
from kafka import KafkaConsumer, KafkaProducer

# Update this for your own recitation section :)
topic = 'recitation-c'

# %% [markdown]
# ### Producer Mode -> Writes Data to Broker

# %%
# Create a producer to write data to kafka
# Ref: https://kafka-python.readthedocs.io/en/master/apidoc/KafkaProducer.html

producer = KafkaProducer(bootstrap_servers='localhost:9092',
                        value_serializer=lambda x: dumps(x).encode('utf-8'),
                        )

cities = ['Pittsbruh', 'Tokyou', 'Sydnay']

# Write data via the producer
print("Writing to Kafka Broker")
for i in range(10):
    data = f'{datetime.now().strftime("%Y-%m-%d %H:%M:%S")},{cities[randint(0,len(cities)-1)]},{randint(18, 32)}ºC'
    print(f"Writing: {data}")
    producer.send(topic=topic, value=data)
    sleep(1)
# Out:
# Writing to Kafka Broker
# Writing: 2024-01-26 11:43:51,Pittsbruh,30ºC
# Writing: 2024-01-26 11:43:52,Tokyou,24ºC
# Writing: 2024-01-26 11:43:53,Pittsbruh,19ºC
# Writing: 2024-01-26 11:43:54,Tokyou,21ºC
# Writing: 2024-01-26 11:43:55,Tokyou,26ºC
# Writing: 2024-01-26 11:43:56,Pittsbruh,24ºC
# Writing: 2024-01-26 11:43:57,Sydnay,29ºC
# Writing: 2024-01-26 11:43:58,Sydnay,27ºC
# Writing: 2024-01-26 11:43:59,Pittsbruh,19ºC
# Writing: 2024-01-26 11:44:00,Pittsbruh,31ºC

# %% [markdown]
# ### Consumer Mode -> Reads Data from Broker

# %%
# Create a consumer to read data from kafka
# Ref: https://kafka-python.readthedocs.io/en/master/apidoc/KafkaConsumer.html

consumer = KafkaConsumer(
    topic,
    bootstrap_servers='localhost:9092',
    auto_offset_reset='earliest', #Experiment with different values
    # Commit that an offset has been read
    enable_auto_commit=True,
    # How often to tell Kafka, an offset has been read
    auto_commit_interval_ms=1000
)

print('Reading Kafka Broker')
for message in consumer:
    message = message.value.decode()
    # Default message.value type is bytes!
    try:
        print(loads(message))
    except:
        print("lmao")
    os.system(f"echo {message} >> kafka_log.csv")
# Out:
# Reading Kafka Broker
# 2024-01-24 21:54:22,New York City,29ºC
# 2024-01-24 21:54:23,Washington D.C.,21ºC
# 2024-01-24 21:54:24,Atlanta,25ºC
# 2024-01-24 21:54:25,New York City,22ºC
# 2024-01-24 21:54:26,Pittsburgh,31ºC
# 2024-01-24 21:54:27,Pittsburgh,27ºC
# 2024-01-24 21:54:28,Washington D.C.,31ºC
# 2024-01-24 21:54:29,New York City,27ºC
# 2024-01-24 21:54:30,Pittsburgh,25ºC
# 2024-01-26 11:27:37,Tokyou,32ºC
# 2024-01-26 11:27:38,Pittsbruh,25ºC
# 2024-01-26 11:27:39,Tokyou,26ºC
# 2024-01-26 11:27:40,Sydnay,30ºC
# 2024-01-26 11:27:41,Sydnay,22ºC
# 2024-01-26 11:27:42,Tokyou,25ºC
# 2024-01-26 11:27:43,Sydnay,30ºC
# 2024-01-26 11:27:44,Sydnay,27ºC
# 2024-01-26 11:27:45,Pittsbruh,30ºC
# 2024-01-26 11:28:45,Delhi,25ºC
# 2024-01-26 11:28:46,Mumbai,28ºC
# 2024-01-26 11:28:47,Mumbai,21ºC
# 2024-01-26 11:28:48,Pittsburgh,31ºC
# 2024-01-26 11:28:49,Mumbai,31ºC
# 2024-01-26 11:28:50,Pittsburgh,22ºC
# 2024-01-26 11:28:51,Delhi,21ºC
# 2024-01-26 11:28:52,Pittsburgh,23ºC
# 2024-01-26 11:28:53,Delhi,26ºC
# 2024-01-26 11:28:54,Mumbai,20ºC
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 15
#       4 consumer = KafkaConsumer(
#       5     topic,
#       6     bootstrap_servers='localhost:9092',
#    (...)
#      11     auto_commit_interval_ms=1000
#      12 )
#      14 print('Reading Kafka Broker')
# ---> 15 for message in consumer:
#      16     message = message.value.decode()
#      17     # Default message.value type is bytes!
#
# File ~/miniconda3/envs/mlip/lib/python3.12/site-packages/kafka/consumer/group.py:1197, in KafkaConsumer.__next__(self)
#    1195     return self.next_v1()
#    1196 else:
# -> 1197     return self.next_v2()
#
# File ~/miniconda3/envs/mlip/lib/python3.12/site-packages/kafka/consumer/group.py:1205, in KafkaConsumer.next_v2(self)
#    1203     self._iterator = self._message_generator_v2()
#    1204 try:
# -> 1205     return next(self._iterator)
#    1206 except StopIteration:
#    1207     self._iterator = None
#
# File ~/miniconda3/envs/mlip/lib/python3.12/site-packages/kafka/consumer/group.py:1120, in KafkaConsumer._message_generator_v2(self)
#    1118 def _message_generator_v2(self):
#    1119     timeout_ms = 1000 * (self._consumer_timeout - time.time())
# -> 1120     record_map = self.poll(timeout_ms=timeout_ms, update_offsets=False)
#    1121     for tp, records in six.iteritems(record_map):
#    1122         # Generators are stateful, and it is possible that the tp / records
#    1123         # here may become stale during iteration -- i.e., we seek to a
#    1124         # different offset, pause consumption, or lose assignment.
#    1125         for record in records:
#    1126             # is_fetchable(tp) should handle assignment changes and offset
#    1127             # resets; for all other changes (e.g., seeks) we'll rely on the
#    1128             # outer function destroying the existing iterator/generator
#    1129             # via self._iterator = None
#
# File ~/miniconda3/envs/mlip/lib/python3.12/site-packages/kafka/consumer/group.py:657, in KafkaConsumer.poll(self, timeout_ms, max_records, update_offsets)
#     655 remaining = timeout_ms
#     656 while not self._closed:
# --> 657     records = self._poll_once(remaining, max_records, update_offsets=update_offsets)
#     658     if records:
#     659         return records
#
# File ~/miniconda3/envs/mlip/lib/python3.12/site-packages/kafka/consumer/group.py:706, in KafkaConsumer._poll_once(self, timeout_ms, max_records, update_offsets)
#     703     self._client.poll(timeout_ms=0)
#     705 timeout_ms = min(timeout_ms, self._coordinator.time_to_next_poll() * 1000)
# --> 706 self._client.poll(timeout_ms=timeout_ms)
#     707 # after the long poll, we should check whether the group needs to rebalance
#     708 # prior to returning data so that the group can stabilize faster
#     709 if self._coordinator.need_rejoin():
#
# File ~/miniconda3/envs/mlip/lib/python3.12/site-packages/kafka/client_async.py:602, in KafkaClient.poll(self, timeout_ms, future)
#     599             timeout = min(timeout, self.config['retry_backoff_ms'])
#     600         timeout = max(0, timeout)  # avoid negative timeouts
# --> 602     self._poll(timeout / 1000)
#     604 # called without the lock to avoid deadlock potential
#     605 # if handlers need to acquire locks
#     606 responses.extend(self._fire_pending_completed_requests())
#
# File ~/miniconda3/envs/mlip/lib/python3.12/site-packages/kafka/client_async.py:634, in KafkaClient._poll(self, timeout)
#     631 self._register_send_sockets()
#     633 start_select = time.time()
# --> 634 ready = self._selector.select(timeout)
#     635 end_select = time.time()
#     636 if self._sensors:
#
# File ~/miniconda3/envs/mlip/lib/python3.12/selectors.py:468, in EpollSelector.select(self, timeout)
#     466 ready = []
#     467 try:
# --> 468     fd_event_list = self._selector.poll(timeout, max_ev)
#     469 except InterruptedError:
#     470     return ready
#
# KeyboardInterrupt:

# %% [markdown]
# # Use kcat!
# It's a CLI (Command Line Interface). Previously known as kafkacat
#
#
# Ref: https://docs.confluent.io/platform/current/app-development/kafkacat-usage.html

# %%
#kcat command: connect to local Kafka broker, specify a topic, and consume messages from the earliest offset

# kcat -b localhost:9092 -t recitation-c -o beginning
